# %%
import os
import requests
from dotenv import load_dotenv
from pathlib import Path
import pandas as pd

# %%
path = Path('./.env')
load_dotenv(path)

API_KEY = os.getenv('COVALENT_API_KEY')

# %%
base_url = 'https://api.covalenthq.com/v1'
chain_id = '1'
contract = "0x7d2768dE32b0b80b7a3454c06BdAc94A69DDc7A9"

## Flashloan Topic
topic = "0x631042c832b07452973831137f2d73e395028b44b250dedc5abb0ee766e168ac"
starting_block = "15010291"
ending_block = "15613530"

# %%
def get_wallet_balance(chain_id, address):
    endpoint = f'/{chain_id}/events/topics/{topic}/?quote-currency=USD&format=JSON&starting-block={starting_block}&ending-block={ending_block}&sender-address={contract}&key={API_KEY}'
    url = base_url + endpoint
    result = requests.get(url).json()
    data = result
    return(data)

# %%
# Example address request
data = get_wallet_balance(chain_id, contract)

# %%
index_col = []
for i in range(0, len(data["data"]["items"])):
    index = data["data"]["items"][i]
    index_col.append(index)

# %%
df = pd.DataFrame(data["data"]["items"])
del df["decoded"]
df
# Out:
#          block_signed_at  block_height  tx_offset  log_offset  \
# 0   2022-06-23T00:43:35Z      15010373        163         470
# 1   2022-06-23T00:44:12Z      15010377         71         264
# 2   2022-06-23T01:12:16Z      15010473          4          55
# 3   2022-06-23T01:39:50Z      15010576        116         326
# 4   2022-06-23T11:03:48Z      15012635         25         133
# ..                   ...           ...        ...         ...
# 95  2022-06-27T13:32:12Z      15034600        167         373
# 96  2022-06-27T13:49:23Z      15034658          3          27
# 97  2022-06-27T15:41:08Z      15035094        110         240
# 98  2022-06-27T21:30:07Z      15036382         77         133
# 99  2022-06-27T22:11:46Z      15036536         51         124
#
#                                               tx_hash  \
# 0   0x303d0eb89a8570b2844b578507a283464f0c8ca03201...
# 1   0x76b487aaca738145651efd0de699eb2b9576bd025efa...
# 2   0xda3cdf8c995a57c7273e7c48a38dafbfac93082b9878...
# 3   0x248fa6e84f237e5a1c0ee7978ef66d1cd369390b7f3e...
# 4   0x074093e3d84dff1bd7df758aff5ee4899604affd3233...
# ..                                                ...
# 95  0xba66a4dcb96624d4aaf55c6d6a772bc44e6e23515d1b...
# 96  0x42b14c58f98a258f573911bf1dda2eb1c94d7ead6643...
# 97  0xd769fe71e940d775de60d900040d3b24af1c6bb56cca...
# 98  0xe1af11c00b801bd377f62c435da00e86b6864e1012c4...
# 99  0x67277375dad34c8b57779cb8df56e844f74ab745a31e...
#
#                                        raw_log_topics  \
# 0   [0x631042c832b07452973831137f2d73e395028b44b25...
# 1   [0x631042c832b07452973831137f2d73e395028b44b25...
# 2   [0x631042c832b07452973831137f2d73e395028b44b25...
# 3   [0x631042c832b07452973831137f2d73e395028b44b25...
# 4   [0x631042c832b07452973831137f2d73e395028b44b25...
# ..                                                ...
# 95  [0x631042c832b07452973831137f2d73e395028b44b25...
# 96  [0x631042c832b07452973831137f2d73e395028b44b25...
# 97  [0x631042c832b07452973831137f2d73e395028b44b25...
# 98  [0x631042c832b07452973831137f2d73e395028b44b25...
# 99  [0x631042c832b07452973831137f2d73e395028b44b25...
#
#     sender_contract_decimals sender_name sender_contract_ticker_symbol  \
# 0                          0        None                          None
# 1                          0        None                          None
# 2                          0        None                          None
# 3                          0        None                          None
# 4                          0        None                          None
# ..                       ...         ...                           ...
# 95                         0        None                          None
# 96                         0        None                          None
# 97                         0        None                          None
# 98                         0        None                          None
# 99                         0        None                          None
#
#                                 sender_address sender_address_label  \
# 0   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 1   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 2   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 3   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 4   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# ..                                         ...                  ...
# 95  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 96  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 97  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 98  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 99  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
#
#                                       sender_logo_url  \
# 0   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 1   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 2   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 3   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 4   https://logos.covalenthq.com/tokens/1/0x7d2768...
# ..                                                ...
# 95  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 96  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 97  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 98  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 99  https://logos.covalenthq.com/tokens/1/0x7d2768...
#
#                                          raw_log_data
# 0   0x00000000000000000000000000000000000000000000...
# 1   0x00000000000000000000000000000000000000000000...
# 2   0x00000000000000000000000000000000000000000000...
# 3   0x00000000000000000000000000000000000000000000...
# 4   0x00000000000000000000000000000000000000000000...
# ..                                                ...
# 95  0x00000000000000000000000000000000000000000000...
# 96  0x00000000000000000000000000000000000000000000...
# 97  0x00000000000000000000000000000000000000000000...
# 98  0x00000000000000000000000000000000000000000000...
# 99  0x00000000000000000000000000000000000000000000...
#
# [100 rows x 13 columns]

# %%
import os
import requests
from dotenv import load_dotenv
from pathlib import Path
import pandas as pd

path = Path('./.env')
load_dotenv(path)

API_KEY = os.getenv('COVALENT_API_KEY')

base_url = 'https://api.covalenthq.com/v1'
chain_id = '1'
contract = "0x7d2768dE32b0b80b7a3454c06BdAc94A69DDc7A9"

## Flashloan Topic
topic = "0x631042c832b07452973831137f2d73e395028b44b250dedc5abb0ee766e168ac"
starting_block = "15010291"
ending_block = "15613530"

def get_flashloan_topics(chain_id, address):
    endpoint = f'/{chain_id}/events/topics/{topic}/?quote-currency=USD&format=JSON&starting-block={starting_block}&ending-block={ending_block}&sender-address={contract}&key={API_KEY}'
    url = base_url + endpoint
    data = requests.get(url).json()
    df = pd.DataFrame(data["data"]["items"])
    del df["decoded"]
    return(df)

# Request
get_flashloan_topics(chain_id, contract)
# Out:
#          block_signed_at  block_height  tx_offset  log_offset  \
# 0   2022-06-23T00:43:35Z      15010373        163         470
# 1   2022-06-23T00:44:12Z      15010377         71         264
# 2   2022-06-23T01:12:16Z      15010473          4          55
# 3   2022-06-23T01:39:50Z      15010576        116         326
# 4   2022-06-23T11:03:48Z      15012635         25         133
# ..                   ...           ...        ...         ...
# 95  2022-06-27T13:32:12Z      15034600        167         373
# 96  2022-06-27T13:49:23Z      15034658          3          27
# 97  2022-06-27T15:41:08Z      15035094        110         240
# 98  2022-06-27T21:30:07Z      15036382         77         133
# 99  2022-06-27T22:11:46Z      15036536         51         124
#
#                                               tx_hash  \
# 0   0x303d0eb89a8570b2844b578507a283464f0c8ca03201...
# 1   0x76b487aaca738145651efd0de699eb2b9576bd025efa...
# 2   0xda3cdf8c995a57c7273e7c48a38dafbfac93082b9878...
# 3   0x248fa6e84f237e5a1c0ee7978ef66d1cd369390b7f3e...
# 4   0x074093e3d84dff1bd7df758aff5ee4899604affd3233...
# ..                                                ...
# 95  0xba66a4dcb96624d4aaf55c6d6a772bc44e6e23515d1b...
# 96  0x42b14c58f98a258f573911bf1dda2eb1c94d7ead6643...
# 97  0xd769fe71e940d775de60d900040d3b24af1c6bb56cca...
# 98  0xe1af11c00b801bd377f62c435da00e86b6864e1012c4...
# 99  0x67277375dad34c8b57779cb8df56e844f74ab745a31e...
#
#                                        raw_log_topics  \
# 0   [0x631042c832b07452973831137f2d73e395028b44b25...
# 1   [0x631042c832b07452973831137f2d73e395028b44b25...
# 2   [0x631042c832b07452973831137f2d73e395028b44b25...
# 3   [0x631042c832b07452973831137f2d73e395028b44b25...
# 4   [0x631042c832b07452973831137f2d73e395028b44b25...
# ..                                                ...
# 95  [0x631042c832b07452973831137f2d73e395028b44b25...
# 96  [0x631042c832b07452973831137f2d73e395028b44b25...
# 97  [0x631042c832b07452973831137f2d73e395028b44b25...
# 98  [0x631042c832b07452973831137f2d73e395028b44b25...
# 99  [0x631042c832b07452973831137f2d73e395028b44b25...
#
#     sender_contract_decimals sender_name sender_contract_ticker_symbol  \
# 0                          0        None                          None
# 1                          0        None                          None
# 2                          0        None                          None
# 3                          0        None                          None
# 4                          0        None                          None
# ..                       ...         ...                           ...
# 95                         0        None                          None
# 96                         0        None                          None
# 97                         0        None                          None
# 98                         0        None                          None
# 99                         0        None                          None
#
#                                 sender_address sender_address_label  \
# 0   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 1   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 2   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 3   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 4   0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# ..                                         ...                  ...
# 95  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 96  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 97  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 98  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
# 99  0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9                 None
#
#                                       sender_logo_url  \
# 0   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 1   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 2   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 3   https://logos.covalenthq.com/tokens/1/0x7d2768...
# 4   https://logos.covalenthq.com/tokens/1/0x7d2768...
# ..                                                ...
# 95  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 96  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 97  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 98  https://logos.covalenthq.com/tokens/1/0x7d2768...
# 99  https://logos.covalenthq.com/tokens/1/0x7d2768...
#
#                                          raw_log_data
# 0   0x00000000000000000000000000000000000000000000...
# 1   0x00000000000000000000000000000000000000000000...
# 2   0x00000000000000000000000000000000000000000000...
# 3   0x00000000000000000000000000000000000000000000...
# 4   0x00000000000000000000000000000000000000000000...
# ..                                                ...
# 95  0x00000000000000000000000000000000000000000000...
# 96  0x00000000000000000000000000000000000000000000...
# 97  0x00000000000000000000000000000000000000000000...
# 98  0x00000000000000000000000000000000000000000000...
# 99  0x00000000000000000000000000000000000000000000...
#
# [100 rows x 13 columns]
